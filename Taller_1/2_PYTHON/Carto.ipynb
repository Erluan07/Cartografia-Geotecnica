# %%
import rasterio as rio
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Requirement already satisfied: rasterio in c:\users\erluan\anaconda3\envs\cartografia\lib\site-packages (1.3.8.post2)
# Requirement already satisfied: affine in c:\users\erluan\anaconda3\envs\cartografia\lib\site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in c:\users\erluan\anaconda3\envs\cartografia\lib\site-packages (from rasterio) (23.1.0)
# Requirement already satisfied: certifi in c:\users\erluan\anaconda3\envs\cartografia\lib\site-packages (from rasterio) (2023.7.22)
# Requirement already satisfied: click>=4.0 in c:\users\erluan\anaconda3\envs\cartografia\lib\site-packages (from rasterio) (8.0.4)
# Requirement already satisfied: cligj>=0.5 in c:\users\erluan\anaconda3\envs\cartografia\lib\site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in c:\users\erluan\anaconda3\envs\cartografia\lib\site-packages (from rasterio) (1.25.2)
# Requirement already satisfied: snuggs>=1.4.1 in c:\users\erluan\anaconda3\envs\cartografia\lib\site-packages (from rasterio) (1.4.7)
# Requirement already satisfied: click-plugins in c:\users\erluan\anaconda3\envs\cartografia\lib\site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in c:\users\erluan\anaconda3\envs\cartografia\lib\site-packages (from rasterio) (68.0.0)
# Requirement already satisfied: colorama in c:\users\erluan\anaconda3\envs\cartografia\lib\site-packages (from click>=4.0->rasterio) (0.4.6)
# Requirement already satisfied: pyparsing>=2.1.6 in c:\users\erluan\anaconda3\envs\cartografia\lib\site-packages (from snuggs>=1.4.1->rasterio) (3.0.9)

# %%
raster = rio.open("https://github.com/Erluan07/Cartografia-Geotecnica/blob/main/Taller_1/2_PYTHON/Eventos.tif?raw=true")

#raster = rio.open("C:\Carto\Movimientos.tif")
inventario=raster.read(1)
print(inventario.shape)
plt.imshow(inventario)
plt.colorbar();
# Out:
# (5713, 5293)

# %%
np.unique(inventario)
# Out:
# array([0, 1], dtype=uint8)

# %%
raster = rio.open("https://github.com/Erluan07/Cartografia-Geotecnica/blob/main/Taller_1/2_PYTHON/Limite.tif?raw=true")
msk=raster.read_masks(1)
msk=np.where(msk==0,np.nan,msk)
plt.imshow(msk)
plt.colorbar();

# %%
inventario=msk*inventario
inventario=np.where(inventario==255,1,inventario)
plt.imshow(inventario)
plt.colorbar();
